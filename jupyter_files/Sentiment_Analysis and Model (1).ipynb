# %%
import pandas as pd
df=pd.read_csv('cleaned_file.csv')

# %%
df.to_csv('cleaned_file.csv', index=False)

# %%
pip install transformers torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: transformers in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (4.32.1)
# Requirement already satisfied: torch in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: filelock in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import BertTokenizer,BertForSequenceClassification
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# 2024-09-19 08:55:39.919270: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
import torch

# %%
df
# Out:
#                                          cleaned_text  \
# 0   please use thread discus portfolio learn stock...
# 1   daily discussion run monday friday including t...
# 2   blackrock preparing launch bn artificial intel...
# 3   intuitive machine nasdaq lunr awarded near spa...
# 4   good morning trader investor rstocks sub welco...
# ..                                                ...
# 95  taiwan semiconductor nysetsm said tuesday sale...
# 96  sept reuters boeing ban open new tab said tues...
# 97  google billion euro fine upheld europe top cou...
# 98  watched video online trying understand covered...
# 99  goldman sachs post roughly million pretax hit ...
#
#                                         cleaned_title
# 0   rate my portfolio rstocks quarterly thread sep...
# 1              rstocks daily discussion wednesday sep
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4                wednesday premarket news stock mover
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96   boeing delivers jet in august up from a year ago
# 97  google billion euro fine upheld by europe top ...
# 98                               selling call and put
# 99  goldman sachs to post million hit to third qua...
#
# [100 rows x 2 columns]

# %%
df['combined'] = df['cleaned_title'] + " " + df['cleaned_text']

# %%
df
# Out:
#                                          cleaned_text  \
# 0   please use thread discus portfolio learn stock...
# 1   daily discussion run monday friday including t...
# 2   blackrock preparing launch bn artificial intel...
# 3   intuitive machine nasdaq lunr awarded near spa...
# 4   good morning trader investor rstocks sub welco...
# ..                                                ...
# 95  taiwan semiconductor nysetsm said tuesday sale...
# 96  sept reuters boeing ban open new tab said tues...
# 97  google billion euro fine upheld europe top cou...
# 98  watched video online trying understand covered...
# 99  goldman sachs post roughly million pretax hit ...
#
#                                         cleaned_title  \
# 0   rate my portfolio rstocks quarterly thread sep...
# 1              rstocks daily discussion wednesday sep
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4                wednesday premarket news stock mover
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96   boeing delivers jet in august up from a year ago
# 97  google billion euro fine upheld by europe top ...
# 98                               selling call and put
# 99  goldman sachs to post million hit to third qua...
#
#                                              combined
# 0   rate my portfolio rstocks quarterly thread sep...
# 1   rstocks daily discussion wednesday sep daily d...
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4   wednesday premarket news stock mover good morn...
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96  boeing delivers jet in august up from a year a...
# 97  google billion euro fine upheld by europe top ...
# 98  selling call and put watched video online tryi...
# 99  goldman sachs to post million hit to third qua...
#
# [100 rows x 3 columns]

# %%
df
# Out:
#                                          cleaned_text  \
# 0   please use thread discus portfolio learn stock...
# 1   daily discussion run monday friday including t...
# 2   blackrock preparing launch bn artificial intel...
# 3   intuitive machine nasdaq lunr awarded near spa...
# 4   good morning trader investor rstocks sub welco...
# ..                                                ...
# 95  taiwan semiconductor nysetsm said tuesday sale...
# 96  sept reuters boeing ban open new tab said tues...
# 97  google billion euro fine upheld europe top cou...
# 98  watched video online trying understand covered...
# 99  goldman sachs post roughly million pretax hit ...
#
#                                         cleaned_title  \
# 0   rate my portfolio rstocks quarterly thread sep...
# 1              rstocks daily discussion wednesday sep
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4                wednesday premarket news stock mover
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96   boeing delivers jet in august up from a year ago
# 97  google billion euro fine upheld by europe top ...
# 98                               selling call and put
# 99  goldman sachs to post million hit to third qua...
#
#                                              combined
# 0   rate my portfolio rstocks quarterly thread sep...
# 1   rstocks daily discussion wednesday sep daily d...
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4   wednesday premarket news stock mover good morn...
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96  boeing delivers jet in august up from a year a...
# 97  google billion euro fine upheld by europe top ...
# 98  selling call and put watched video online tryi...
# 99  goldman sachs to post million hit to third qua...
#
# [100 rows x 3 columns]

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: textblob in /home/08c3e540-0e16-4e3c-87af-0e7b2f05d109/.local/lib/python3.10/site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from nltk>=3.8->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages (from nltk>=3.8->textblob) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def classify_sentiment(text):
    blob = TextBlob(text)
    if blob.sentiment.polarity> 0:
        return 'positive'
    elif blob.sentiment.polarity < 0:
        return  'negative'
    else:
        return 'neutral'

# %%
from textblob import TextBlob

# %%
df['sentiment'] = df['combined'].apply(classify_sentiment)

# %%
df
# Out:
#                                          cleaned_text  \
# 0   please use thread discus portfolio learn stock...
# 1   daily discussion run monday friday including t...
# 2   blackrock preparing launch bn artificial intel...
# 3   intuitive machine nasdaq lunr awarded near spa...
# 4   good morning trader investor rstocks sub welco...
# ..                                                ...
# 95  taiwan semiconductor nysetsm said tuesday sale...
# 96  sept reuters boeing ban open new tab said tues...
# 97  google billion euro fine upheld europe top cou...
# 98  watched video online trying understand covered...
# 99  goldman sachs post roughly million pretax hit ...
#
#                                         cleaned_title  \
# 0   rate my portfolio rstocks quarterly thread sep...
# 1              rstocks daily discussion wednesday sep
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4                wednesday premarket news stock mover
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96   boeing delivers jet in august up from a year ago
# 97  google billion euro fine upheld by europe top ...
# 98                               selling call and put
# 99  goldman sachs to post million hit to third qua...
#
#                                              combined sentiment
# 0   rate my portfolio rstocks quarterly thread sep...  positive
# 1   rstocks daily discussion wednesday sep daily d...  negative
# 2   blackrock and microsoft plan bn fund to invest...  positive
# 3   nasa award lunr near space network contract po...  negative
# 4   wednesday premarket news stock mover good morn...  positive
# ..                                                ...       ...
# 95  taiwan semiconductor august sale surge a ai de...  negative
# 96  boeing delivers jet in august up from a year a...  positive
# 97  google billion euro fine upheld by europe top ...  positive
# 98  selling call and put watched video online tryi...  negative
# 99  goldman sachs to post million hit to third qua...  negative
#
# [100 rows x 4 columns]

# %%
df.drop(columns=['outcome'],inplace=True)

# %%
df
# Out:
#                                          cleaned_text  \
# 0   please use thread discus portfolio learn stock...
# 1   daily discussion run monday friday including t...
# 2   blackrock preparing launch bn artificial intel...
# 3   intuitive machine nasdaq lunr awarded near spa...
# 4   good morning trader investor rstocks sub welco...
# ..                                                ...
# 95  taiwan semiconductor nysetsm said tuesday sale...
# 96  sept reuters boeing ban open new tab said tues...
# 97  google billion euro fine upheld europe top cou...
# 98  watched video online trying understand covered...
# 99  goldman sachs post roughly million pretax hit ...
#
#                                         cleaned_title  \
# 0   rate my portfolio rstocks quarterly thread sep...
# 1              rstocks daily discussion wednesday sep
# 2   blackrock and microsoft plan bn fund to invest...
# 3   nasa award lunr near space network contract po...
# 4                wednesday premarket news stock mover
# ..                                                ...
# 95  taiwan semiconductor august sale surge a ai de...
# 96   boeing delivers jet in august up from a year ago
# 97  google billion euro fine upheld by europe top ...
# 98                               selling call and put
# 99  goldman sachs to post million hit to third qua...
#
#                                              combined sentiment
# 0   rate my portfolio rstocks quarterly thread sep...  positive
# 1   rstocks daily discussion wednesday sep daily d...  negative
# 2   blackrock and microsoft plan bn fund to invest...  positive
# 3   nasa award lunr near space network contract po...  negative
# 4   wednesday premarket news stock mover good morn...  positive
# ..                                                ...       ...
# 95  taiwan semiconductor august sale surge a ai de...  negative
# 96  boeing delivers jet in august up from a year a...  positive
# 97  google billion euro fine upheld by europe top ...  positive
# 98  selling call and put watched video online tryi...  negative
# 99  goldman sachs to post million hit to third qua...  negative
#
# [100 rows x 4 columns]
